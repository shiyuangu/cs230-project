# %%
import numpy as np 
import pandas as pd
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score
from sklearn.utils import shuffle
import keras
from keras.layers import Input, LSTM, Dense,Lambda
from keras.models import Model
from keras.utils import plot_model
from keras.layers.embeddings import Embedding
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.layers import multiply
from matplotlib import pyplot as plt
import gensim.downloader as api
from gensim.models.keyedvectors import Word2VecKeyedVectors
# Out:
# Using TensorFlow backend.

# %%
#use pre-trained:'Wikipedia 2014 + Gigaword 5 (6B tokens, uncased)'
#vocab: 400K
# api.info("glove-wiki-gigaword-100")
#word_vectors = api.load("glove-wiki-gigaword-100")
#word_vectors.save("glove-wiki-gigaword-100.model")
word_vectors = Word2VecKeyedVectors.load("glove-wiki-gigaword-100.model")

# %%
#define the model 
max_qlen = 50 #Truncate if longer
vocab_len = len(word_vectors.vocab)+1
wv_len = word_vectors.get_vector("the").shape[0]

# %%
df_train = pd.read_pickle("train_pp.pkl")
df_test = pd.read_pickle("test_pp.pkl")

# %%
df_train.head()
# Out:
#             id    qid1    qid2  \
# 145367  145367  229850  229851
# 123169  123169   98309  199206
# 57880    57880  101653  101654
# 213043  213043  318261  318262
# 204901  204901  307914  307915
#
#                                                 question1  \
# 145367                   Is there only one consciousness?
# 123169  Which is a suitable solar panel installation p...
# 57880   Is there any idea for a new and useful mini pr...
# 213043  What does it mean if a girl cries after hurtin...
# 204901  What are some wholesale drop shippers that hav...
#
#                                                 question2  is_duplicate  \
# 145367                 Is consciousness one for everyone?             1
# 123169  Which is a suitable solar panel installation p...             0
# 57880   Are there any new topics in computer science t...             0
# 213043  What does it mean if a girl cries without any ...             0
# 204901  What portrait lenses are compatible with the C...             0
#
#                                                   words_1  \
# 145367           [is, there, only, one, consciousness, ?]
# 123169  [which, is, a, suitable, solar, panel, install...
# 57880   [is, there, any, idea, for, a, new, and, usefu...
# 213043  [what, doe, it, mean, if, a, girl, cry, after,...
# 204901  [what, are, some, wholesale, drop, shipper, th...
#
#                                                   words_2 end_punc_1  \
# 145367         [is, consciousness, one, for, everyone, ?]          ?
# 123169  [which, is, a, suitable, solar, panel, install...          ?
# 57880   [are, there, any, new, topic, in, computer, sc...          ?
# 213043  [what, doe, it, mean, if, a, girl, cry, withou...          ?
# 204901  [what, portrait, lens, are, compatible, with, ...          ?
#
#        end_punc_2  is_same_end_punc
# 145367          ?              True
# 123169          ?              True
# 57880           ?              True
# 213043          ?              True
# 204901          ?              True

# %%
def words2ints(words,max_len):
    """
    turn a list words to their word indices; padd or truncate to  max_len;
    @params words: List[str]
    return List[int]
    """
    rv = np.zeros((max_len,))
    for i,w in enumerate(words[:max_len]): 
        if w in word_vectors.vocab: 
            rv[i]=word_vectors.vocab[w].index + 1 #Don't forget to shift since keras use 0 for OOV 
        else: 
            rv[i]=0 
    return rv

# %%
df_train['q1_indices'] = df_train['words_1'].apply(lambda x: words2ints(x,max_qlen))
df_train['q2_indices'] = df_train['words_2'].apply(lambda x: words2ints(x,max_qlen))
df_test['q1_indices'] = df_test['words_1'].apply(lambda x: words2ints(x,max_qlen))
df_test['q2_indices'] = df_test['words_2'].apply(lambda x: words2ints(x,max_qlen))

# %%
df_train.head()
# Out:
#             id    qid1    qid2  \
# 145367  145367  229850  229851
# 123169  123169   98309  199206
# 57880    57880  101653  101654
# 213043  213043  318261  318262
# 204901  204901  307914  307915
#
#                                                 question1  \
# 145367                   Is there only one consciousness?
# 123169  Which is a suitable solar panel installation p...
# 57880   Is there any idea for a new and useful mini pr...
# 213043  What does it mean if a girl cries after hurtin...
# 204901  What are some wholesale drop shippers that hav...
#
#                                                 question2  is_duplicate  \
# 145367                 Is consciousness one for everyone?             1
# 123169  Which is a suitable solar panel installation p...             0
# 57880   Are there any new topics in computer science t...             0
# 213043  What does it mean if a girl cries without any ...             0
# 204901  What portrait lenses are compatible with the C...             0
#
#                                                   words_1  \
# 145367           [is, there, only, one, consciousness, ?]
# 123169  [which, is, a, suitable, solar, panel, install...
# 57880   [is, there, any, idea, for, a, new, and, usefu...
# 213043  [what, doe, it, mean, if, a, girl, cry, after,...
# 204901  [what, are, some, wholesale, drop, shipper, th...
#
#                                                   words_2 end_punc_1  \
# 145367         [is, consciousness, one, for, everyone, ?]          ?
# 123169  [which, is, a, suitable, solar, panel, install...          ?
# 57880   [are, there, any, new, topic, in, computer, sc...          ?
# 213043  [what, doe, it, mean, if, a, girl, cry, withou...          ?
# 204901  [what, portrait, lens, are, compatible, with, ...          ?
#
#        end_punc_2  is_same_end_punc  \
# 145367          ?              True
# 123169          ?              True
# 57880           ?              True
# 213043          ?              True
# 204901          ?              True
#
#                                                q1_indices  \
# 145367  [15.0, 64.0, 92.0, 49.0, 8658.0, 189.0, 0.0, 0...
# 123169  [43.0, 15.0, 8.0, 7089.0, 4709.0, 1909.0, 7389...
# 57880   [15.0, 64.0, 131.0, 1160.0, 11.0, 8.0, 51.0, 6...
# 213043  [103.0, 14220.0, 21.0, 1703.0, 84.0, 8.0, 1750...
# 204901  [103.0, 33.0, 78.0, 7531.0, 1561.0, 59002.0, 1...
#
#                                                q2_indices
# 145367  [15.0, 8658.0, 49.0, 11.0, 1403.0, 189.0, 0.0,...
# 123169  [43.0, 15.0, 8.0, 7089.0, 4709.0, 1909.0, 7389...
# 57880   [33.0, 64.0, 131.0, 51.0, 6284.0, 7.0, 952.0, ...
# 213043  [103.0, 14220.0, 21.0, 1703.0, 84.0, 8.0, 1750...
# 204901  [103.0, 6034.0, 9025.0, 33.0, 11631.0, 18.0, 1...

# %%
q1_seq_train = np.vstack(df_train.q1_indices.values)
q2_seq_train = np.vstack(df_train.q2_indices.values)
q1_seq_test = np.vstack(df_test.q1_indices.values)
q2_seq_test = np.vstack(df_test.q2_indices.values)
y_train = df_train.is_duplicate.values
y_test = df_test.is_duplicate.values

# %%
q1_seq_train.shape, q2_seq_train.shape, y_train.shape
# Out:
# ((323432, 50), (323432, 50), (323432,))

# %%
df_train.shape,df_test.shape
# Out:
# ((323432, 13), (80858, 13))

# %%
#embedding = word_vectors.get_keras_embedding() #Don't use this, gensim doesn't consider OOV https://github.com/RaRe-Technologies/gensim/blob/2ccc82bf50bcfbee44932c160db076a873cf893e/gensim/models/keyedvectors.py#L1491
embd_weights = np.zeros((vocab_len,wv_len))
embd_weights[1:,:] = word_vectors.vectors

# %%
#define the model 
word2vec_layer = Embedding(vocab_len, wv_len, trainable=False,weights=[embd_weights],name="word2vec") #check this Emoji and gensim set the weight in different ways
get_word_weight_layer = Embedding(vocab_len, 1, weights=[np.ones((vocab_len,1))], trainable=True,name="get_word_weight") #generalize tf-idf
reduce_layer = Lambda(lambda x: K.sum(x, axis=1), output_shape=lambda s: (s[0], s[2]),name="vector_reduction")


q1 = Input(shape=(max_qlen,),name="question_1")
q2 = Input(shape=(max_qlen,),name="question_2")

q1_wv,q2_wv = map(word2vec_layer,[q1,q2])
q1_ww,q2_ww = map(get_word_weight_layer,[q1,q2])
q1_wv_ww,q2_wv_ww = map(multiply, [[q1_wv,q1_ww], [q2_wv,q2_ww]])
q1_final_vec, q2_final_vec = map(reduce_layer, [q1_wv_ww,q2_wv_ww])
# q1_wv = word2vec_layer(q1)
# q1_ww = get_word_weight_layer(q1)
# q1_wv_ww = multiply([q1_wv,q1_ww])
# q1_final_vec = reduce_layer(q1_wv_ww)

# q2_wv = word2vec_layer(q2)
# q2_ww = get_word_weight_layer(q2)
# q2_wv_ww = multiply([q2_wv,q2_ww])
# q2_final_vec = reduce_layer(q2_wv_ww)

merged_vector = keras.layers.concatenate([q1_final_vec, q2_final_vec], axis=-1,name="merge")
predictions = Dense(1, activation='sigmoid',name="sigmoid")(merged_vector)
model = Model(inputs=[q1, q2], outputs=predictions)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
#use batch_size = 32 for CPU, batch_size = 8192 for GPU 
callbacks = [EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
# model.fit([q1_seq_train,q2_seq_train], y_train, epochs = 200, batch_size = 8192, shuffle=True,
#          validation_data=([q1_seq_test,q2_seq_test],y_test),
#          callbacks=callbacks) #200  epochs in total
q1_seq_train,q2_seq_train, y_train = shuffle(q1_seq_train,q2_seq_train, y_train, random_state=4)
model.fit([q1_seq_train,q2_seq_train], y_train, epochs = 400, batch_size = 8192, shuffle=True,
         validation_split=0.1,
        callbacks=callbacks) #100 epoches in total
# Out:
# Train on 291088 samples, validate on 32344 samples
# Epoch 1/400
# 291088/291088 [==============================] - 1s 3us/step - loss: 1.1259 - acc: 0.5543 - val_loss: 0.8825 - val_acc: 0.5730
# Epoch 2/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.8283 - acc: 0.5874 - val_loss: 0.7766 - val_acc: 0.5924
# Epoch 3/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.7495 - acc: 0.6038 - val_loss: 0.7198 - val_acc: 0.6091
# Epoch 4/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.7040 - acc: 0.6165 - val_loss: 0.6850 - val_acc: 0.6201
# Epoch 5/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6754 - acc: 0.6264 - val_loss: 0.6622 - val_acc: 0.6305
# Epoch 6/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6557 - acc: 0.6340 - val_loss: 0.6465 - val_acc: 0.6367
# Epoch 7/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6420 - acc: 0.6416 - val_loss: 0.6349 - val_acc: 0.6436
# Epoch 8/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6317 - acc: 0.6470 - val_loss: 0.6260 - val_acc: 0.6487
# Epoch 9/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6240 - acc: 0.6523 - val_loss: 0.6191 - val_acc: 0.6548
# Epoch 10/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6174 - acc: 0.6562 - val_loss: 0.6135 - val_acc: 0.6585
# Epoch 11/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6122 - acc: 0.6604 - val_loss: 0.6085 - val_acc: 0.6628
# Epoch 12/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6078 - acc: 0.6639 - val_loss: 0.6045 - val_acc: 0.6663
# Epoch 13/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6042 - acc: 0.6665 - val_loss: 0.6029 - val_acc: 0.6705
# Epoch 14/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.6013 - acc: 0.6694 - val_loss: 0.5984 - val_acc: 0.6712
# Epoch 15/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5977 - acc: 0.6724 - val_loss: 0.5953 - val_acc: 0.6756
# Epoch 16/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5952 - acc: 0.6749 - val_loss: 0.5927 - val_acc: 0.6777
# Epoch 17/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5928 - acc: 0.6768 - val_loss: 0.5908 - val_acc: 0.6790
# Epoch 18/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5904 - acc: 0.6793 - val_loss: 0.5900 - val_acc: 0.6806
# Epoch 19/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5891 - acc: 0.6805 - val_loss: 0.5867 - val_acc: 0.6816
# Epoch 20/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5861 - acc: 0.6835 - val_loss: 0.5848 - val_acc: 0.6839
# Epoch 21/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5843 - acc: 0.6851 - val_loss: 0.5830 - val_acc: 0.6852
# Epoch 22/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5826 - acc: 0.6869 - val_loss: 0.5813 - val_acc: 0.6873
# Epoch 23/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5807 - acc: 0.6886 - val_loss: 0.5801 - val_acc: 0.6901
# Epoch 24/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5792 - acc: 0.6902 - val_loss: 0.5779 - val_acc: 0.6909
# Epoch 25/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5776 - acc: 0.6919 - val_loss: 0.5778 - val_acc: 0.6930
# Epoch 26/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5759 - acc: 0.6942 - val_loss: 0.5753 - val_acc: 0.6938
# Epoch 27/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5744 - acc: 0.6951 - val_loss: 0.5737 - val_acc: 0.6948
# Epoch 28/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5727 - acc: 0.6971 - val_loss: 0.5725 - val_acc: 0.6959
# Epoch 29/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5712 - acc: 0.6984 - val_loss: 0.5714 - val_acc: 0.6977
# Epoch 30/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5697 - acc: 0.6999 - val_loss: 0.5700 - val_acc: 0.6987
# Epoch 31/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5683 - acc: 0.7013 - val_loss: 0.5693 - val_acc: 0.7004
# Epoch 32/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5670 - acc: 0.7027 - val_loss: 0.5675 - val_acc: 0.7011
# Epoch 33/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5657 - acc: 0.7042 - val_loss: 0.5665 - val_acc: 0.7025
# Epoch 34/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5645 - acc: 0.7053 - val_loss: 0.5659 - val_acc: 0.7038
# Epoch 35/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5631 - acc: 0.7064 - val_loss: 0.5642 - val_acc: 0.7051
# Epoch 36/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5620 - acc: 0.7075 - val_loss: 0.5632 - val_acc: 0.7062
# Epoch 37/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5609 - acc: 0.7081 - val_loss: 0.5626 - val_acc: 0.7074
# Epoch 38/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5601 - acc: 0.7090 - val_loss: 0.5631 - val_acc: 0.7054
# Epoch 39/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5586 - acc: 0.7099 - val_loss: 0.5601 - val_acc: 0.7088
# Epoch 40/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5568 - acc: 0.7119 - val_loss: 0.5591 - val_acc: 0.7103
# Epoch 41/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5560 - acc: 0.7127 - val_loss: 0.5595 - val_acc: 0.7086
# Epoch 42/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5548 - acc: 0.7134 - val_loss: 0.5577 - val_acc: 0.7098
# Epoch 43/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5534 - acc: 0.7151 - val_loss: 0.5570 - val_acc: 0.7111
# Epoch 44/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5522 - acc: 0.7157 - val_loss: 0.5563 - val_acc: 0.7130
# Epoch 45/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5509 - acc: 0.7169 - val_loss: 0.5550 - val_acc: 0.7129
# Epoch 46/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5502 - acc: 0.7173 - val_loss: 0.5542 - val_acc: 0.7138
# Epoch 47/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5489 - acc: 0.7181 - val_loss: 0.5531 - val_acc: 0.7150
# Epoch 48/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5478 - acc: 0.7191 - val_loss: 0.5521 - val_acc: 0.7149
# Epoch 49/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5464 - acc: 0.7204 - val_loss: 0.5531 - val_acc: 0.7167
# Epoch 50/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5455 - acc: 0.7215 - val_loss: 0.5508 - val_acc: 0.7162
# Epoch 51/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5450 - acc: 0.7211 - val_loss: 0.5505 - val_acc: 0.7160
# Epoch 52/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5433 - acc: 0.7230 - val_loss: 0.5490 - val_acc: 0.7182
# Epoch 53/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5421 - acc: 0.7241 - val_loss: 0.5482 - val_acc: 0.7185
# Epoch 54/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5411 - acc: 0.7249 - val_loss: 0.5474 - val_acc: 0.7205
# Epoch 55/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5401 - acc: 0.7258 - val_loss: 0.5470 - val_acc: 0.7201
# Epoch 56/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5393 - acc: 0.7260 - val_loss: 0.5460 - val_acc: 0.7211
# Epoch 57/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5381 - acc: 0.7271 - val_loss: 0.5454 - val_acc: 0.7218
# Epoch 58/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5370 - acc: 0.7279 - val_loss: 0.5446 - val_acc: 0.7228
# Epoch 59/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5360 - acc: 0.7292 - val_loss: 0.5443 - val_acc: 0.7228
# Epoch 60/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5351 - acc: 0.7293 - val_loss: 0.5437 - val_acc: 0.7241
# Epoch 61/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5340 - acc: 0.7307 - val_loss: 0.5434 - val_acc: 0.7237
# Epoch 62/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5331 - acc: 0.7314 - val_loss: 0.5421 - val_acc: 0.7251
# Epoch 63/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5322 - acc: 0.7316 - val_loss: 0.5413 - val_acc: 0.7254
# Epoch 64/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5311 - acc: 0.7327 - val_loss: 0.5407 - val_acc: 0.7256
# Epoch 65/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5303 - acc: 0.7335 - val_loss: 0.5403 - val_acc: 0.7266
# Epoch 66/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5294 - acc: 0.7340 - val_loss: 0.5397 - val_acc: 0.7264
# Epoch 67/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5283 - acc: 0.7349 - val_loss: 0.5390 - val_acc: 0.7272
# Epoch 68/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5273 - acc: 0.7356 - val_loss: 0.5384 - val_acc: 0.7279
# Epoch 69/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5266 - acc: 0.7358 - val_loss: 0.5383 - val_acc: 0.7293
# Epoch 70/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5258 - acc: 0.7367 - val_loss: 0.5379 - val_acc: 0.7284
# Epoch 71/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5246 - acc: 0.7375 - val_loss: 0.5368 - val_acc: 0.7304
# Epoch 72/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5238 - acc: 0.7383 - val_loss: 0.5374 - val_acc: 0.7293
# Epoch 73/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5229 - acc: 0.7389 - val_loss: 0.5360 - val_acc: 0.7300
# Epoch 74/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5221 - acc: 0.7394 - val_loss: 0.5352 - val_acc: 0.7314
# Epoch 75/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5210 - acc: 0.7401 - val_loss: 0.5349 - val_acc: 0.7321
# Epoch 76/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5202 - acc: 0.7408 - val_loss: 0.5344 - val_acc: 0.7321
# Epoch 77/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5193 - acc: 0.7411 - val_loss: 0.5340 - val_acc: 0.7328
# Epoch 78/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5186 - acc: 0.7421 - val_loss: 0.5334 - val_acc: 0.7332
# Epoch 79/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5176 - acc: 0.7426 - val_loss: 0.5329 - val_acc: 0.7345
# Epoch 80/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5169 - acc: 0.7428 - val_loss: 0.5338 - val_acc: 0.7336
# Epoch 81/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5163 - acc: 0.7433 - val_loss: 0.5323 - val_acc: 0.7353
# Epoch 82/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5154 - acc: 0.7439 - val_loss: 0.5321 - val_acc: 0.7351
# Epoch 83/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5146 - acc: 0.7444 - val_loss: 0.5312 - val_acc: 0.7356
# Epoch 84/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5137 - acc: 0.7452 - val_loss: 0.5309 - val_acc: 0.7361
# Epoch 85/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5128 - acc: 0.7458 - val_loss: 0.5306 - val_acc: 0.7368
# Epoch 86/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5122 - acc: 0.7461 - val_loss: 0.5301 - val_acc: 0.7371
# Epoch 87/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5113 - acc: 0.7470 - val_loss: 0.5300 - val_acc: 0.7368
# Epoch 88/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5109 - acc: 0.7470 - val_loss: 0.5294 - val_acc: 0.7377
# Epoch 89/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5098 - acc: 0.7477 - val_loss: 0.5291 - val_acc: 0.7390
# Epoch 90/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5091 - acc: 0.7480 - val_loss: 0.5288 - val_acc: 0.7387
# Epoch 91/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5084 - acc: 0.7486 - val_loss: 0.5285 - val_acc: 0.7388
# Epoch 92/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5075 - acc: 0.7493 - val_loss: 0.5286 - val_acc: 0.7394
# Epoch 93/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5072 - acc: 0.7493 - val_loss: 0.5289 - val_acc: 0.7400
# Epoch 94/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5063 - acc: 0.7498 - val_loss: 0.5279 - val_acc: 0.7406
# Epoch 95/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5056 - acc: 0.7503 - val_loss: 0.5272 - val_acc: 0.7399
# Epoch 96/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5047 - acc: 0.7509 - val_loss: 0.5269 - val_acc: 0.7398
# Epoch 97/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5042 - acc: 0.7512 - val_loss: 0.5267 - val_acc: 0.7404
# Epoch 98/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5033 - acc: 0.7517 - val_loss: 0.5265 - val_acc: 0.7407
# Epoch 99/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5029 - acc: 0.7521 - val_loss: 0.5264 - val_acc: 0.7403
# Epoch 100/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5025 - acc: 0.7523 - val_loss: 0.5266 - val_acc: 0.7425
# Epoch 101/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5015 - acc: 0.7530 - val_loss: 0.5257 - val_acc: 0.7412
# Epoch 102/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5007 - acc: 0.7534 - val_loss: 0.5255 - val_acc: 0.7413
# Epoch 103/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.5001 - acc: 0.7537 - val_loss: 0.5253 - val_acc: 0.7421
# Epoch 104/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4995 - acc: 0.7540 - val_loss: 0.5251 - val_acc: 0.7418
# Epoch 105/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4989 - acc: 0.7543 - val_loss: 0.5250 - val_acc: 0.7419
# Epoch 106/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4982 - acc: 0.7550 - val_loss: 0.5248 - val_acc: 0.7425
# Epoch 107/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4975 - acc: 0.7554 - val_loss: 0.5245 - val_acc: 0.7425
# Epoch 108/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4971 - acc: 0.7556 - val_loss: 0.5253 - val_acc: 0.7405
# Epoch 109/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4965 - acc: 0.7560 - val_loss: 0.5243 - val_acc: 0.7430
# Epoch 110/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4958 - acc: 0.7567 - val_loss: 0.5246 - val_acc: 0.7417
# Epoch 111/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4954 - acc: 0.7564 - val_loss: 0.5239 - val_acc: 0.7431
# Epoch 112/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4946 - acc: 0.7572 - val_loss: 0.5243 - val_acc: 0.7436
# Epoch 113/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4939 - acc: 0.7576 - val_loss: 0.5238 - val_acc: 0.7442
# Epoch 114/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4934 - acc: 0.7578 - val_loss: 0.5237 - val_acc: 0.7435
# Epoch 115/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4928 - acc: 0.7581 - val_loss: 0.5234 - val_acc: 0.7438
# Epoch 116/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4923 - acc: 0.7588 - val_loss: 0.5233 - val_acc: 0.7438
# Epoch 117/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4918 - acc: 0.7588 - val_loss: 0.5235 - val_acc: 0.7448
# Epoch 118/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4913 - acc: 0.7591 - val_loss: 0.5234 - val_acc: 0.7434
# Epoch 119/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4907 - acc: 0.7595 - val_loss: 0.5228 - val_acc: 0.7446
# Epoch 120/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4901 - acc: 0.7600 - val_loss: 0.5232 - val_acc: 0.7453
# Epoch 121/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4895 - acc: 0.7599 - val_loss: 0.5227 - val_acc: 0.7451
# Epoch 122/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4889 - acc: 0.7606 - val_loss: 0.5232 - val_acc: 0.7441
# Epoch 123/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4886 - acc: 0.7608 - val_loss: 0.5228 - val_acc: 0.7449
# Epoch 124/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4879 - acc: 0.7612 - val_loss: 0.5227 - val_acc: 0.7447
# Epoch 125/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4873 - acc: 0.7617 - val_loss: 0.5225 - val_acc: 0.7458
# Epoch 126/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4869 - acc: 0.7618 - val_loss: 0.5224 - val_acc: 0.7452
# Epoch 127/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4863 - acc: 0.7623 - val_loss: 0.5226 - val_acc: 0.7464
# Epoch 128/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4858 - acc: 0.7624 - val_loss: 0.5223 - val_acc: 0.7458
# Epoch 129/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4854 - acc: 0.7626 - val_loss: 0.5223 - val_acc: 0.7458
# Epoch 130/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4848 - acc: 0.7630 - val_loss: 0.5223 - val_acc: 0.7450
# Epoch 131/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4842 - acc: 0.7634 - val_loss: 0.5221 - val_acc: 0.7461
# Epoch 132/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4840 - acc: 0.7633 - val_loss: 0.5221 - val_acc: 0.7458
# Epoch 133/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4834 - acc: 0.7640 - val_loss: 0.5221 - val_acc: 0.7462
# Epoch 134/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4829 - acc: 0.7644 - val_loss: 0.5220 - val_acc: 0.7459
# Epoch 135/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4824 - acc: 0.7642 - val_loss: 0.5222 - val_acc: 0.7463
# Epoch 136/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4819 - acc: 0.7648 - val_loss: 0.5220 - val_acc: 0.7464
# Epoch 137/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4813 - acc: 0.7651 - val_loss: 0.5220 - val_acc: 0.7465
# Epoch 138/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4809 - acc: 0.7652 - val_loss: 0.5222 - val_acc: 0.7471
# Epoch 139/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4805 - acc: 0.7654 - val_loss: 0.5220 - val_acc: 0.7471
# Epoch 140/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4805 - acc: 0.7655 - val_loss: 0.5229 - val_acc: 0.7470
# Epoch 141/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4799 - acc: 0.7659 - val_loss: 0.5229 - val_acc: 0.7455
# Epoch 142/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4792 - acc: 0.7662 - val_loss: 0.5220 - val_acc: 0.7471
# Epoch 143/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4787 - acc: 0.7665 - val_loss: 0.5220 - val_acc: 0.7472
# Epoch 144/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4783 - acc: 0.7666 - val_loss: 0.5220 - val_acc: 0.7470
# Epoch 145/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4778 - acc: 0.7672 - val_loss: 0.5221 - val_acc: 0.7472
# Epoch 146/400
# 291088/291088 [==============================] - 1s 2us/step - loss: 0.4774 - acc: 0.7672 - val_loss: 0.5221 - val_acc: 0.7477

# %%
y_pred_test = model.predict([q1_seq_test,q2_seq_test], batch_size=8192,verbose=1)
y_pred_train = model.predict([q1_seq_train,q2_seq_train], batch_size=8192,verbose=1)
# Out:
# 80858/80858 [==============================] - 0s 1us/step
# 323432/323432 [==============================] - 0s 1us/step

# %%
auc_test = roc_auc_score(y_test,y_pred_test)
accuracy_test = accuracy_score(y_test,y_pred_test>0.5)
auc_train = roc_auc_score(y_train,y_pred_train)
accuracy_train = accuracy_score(y_train,y_pred_train>0.5)

print("auc_train=%g, auc_test=%g, accuracy_train=%g, accuracy_test=%g" % (auc_train, auc_test, accuracy_train, accuracy_test))
# Out:
# auc_train=0.828671, auc_test=0.798297, accuracy_train=0.763205, accuracy_test=0.747026

# %%
fpr_train, tpr_train, thresholds_train = roc_curve(y_train,y_pred_train)
fpr_test, tpr_test, thresholds_test = roc_curve(y_test,y_pred_test)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(fpr_train,tpr_train, color="blue", label="train roc, auc=%g" % (auc_train,))
plt.legend()
plt.title("ROC for training data")
plt.subplot(1,2,2)
plt.plot(fpr_test,tpr_test, color="green", label="test roc, auc=%g" % (auc_test,))
plt.legend()
plt.title("ROC for testing data")
# Out:
# Text(0.5,1,'ROC for testing data')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# question_1 (InputLayer)         (None, 50)           0
# __________________________________________________________________________________________________
# question_2 (InputLayer)         (None, 50)           0
# __________________________________________________________________________________________________
# word2vec (Embedding)            (None, 50, 100)      40000100    question_1[0][0]
#                                                                  question_2[0][0]
# __________________________________________________________________________________________________
# get_word_weight (Embedding)     (None, 50, 1)        400001      question_1[0][0]
#                                                                  question_2[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 50, 100)      0           word2vec[0][0]
#                                                                  get_word_weight[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 50, 100)      0           word2vec[1][0]
#                                                                  get_word_weight[1][0]
# __________________________________________________________________________________________________
# vector_reduction (Lambda)       (None, 100)          0           multiply_3[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# merge (Concatenate)             (None, 200)          0           vector_reduction[0][0]
#                                                                  vector_reduction[1][0]
# __________________________________________________________________________________________________
# sigmoid (Dense)                 (None, 1)            201         merge[0][0]
# ==================================================================================================
# Total params: 40,400,302
# Trainable params: 400,202
# Non-trainable params: 40,000,100
# __________________________________________________________________________________________________

# %%
plot_model(model,to_file="model.png")
from IPython.display import Image
Image(filename='model.png')
